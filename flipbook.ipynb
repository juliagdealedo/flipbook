# %% [markdown]
# # FLIPBOOK
# Sacar los fotogramas de un video y plotearlos en un A4 para imprimir y encuadernar

# %%
pip install opencv-python
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.patches as patches
import numpy as np

# %%
# Importar el video
cap=cv2.VideoCapture("vido.MP4")

# %%
# Extraer los fotogramas
i= 1
while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == False:
        break     
    cv2.imwrite("Frame"+ str(i) + ".jpg", frame)
    i += 1
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [175], in <cell line: 11>()
#       8     i += 1
#       9     print(i)
# ---> 11 ret.head()
#
# AttributeError: 'bool' object has no attribute 'head'

# %%
cap.release()
cv2.destroyAllWindows()
# Out:
# None

# %%
# Importar imagenes en una lista
import glob
imagelist2 = glob.glob('/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/*.jpg')

# %%
# ordenar lista por nombre 
# problema, me lo ordena como "str" 1,10,11,12,13... las fotos no quedan en orden
imagelist3 = sorted(imagelist2)
print(imagelist3)
# Out:
# ['/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame1.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame10.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame100.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame101.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame102.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame103.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame104.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame105.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame106.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame107.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame108.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame109.jpg', '/Users/juliag.dealedo/OneDrive - UAM/Ocio/FlipBook python/Frame11.jpg', '/Users/juliag.dealedo/OneDrive - UAM/O
# ...

# %%
# Check la lista de imagenes 
img = mpimg.imread(imagelist2[1])
imgplot = plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Intento de crear un rectangulo (fallido)
rect = pltpatches.Rectangle(xy=(2026, 50.8),
                                    width=1, height=2,
                                    linewidth=2, edgecolor='skyblue',
                                    alpha = 0.5,
                                    facecolor='skyblue', clip_on= False);
plt.show(rect)
print(rect)
# Out:
# Rectangle(xy=(2026, 50.8), width=1, height=2, angle=0)

# %%
# Loop para plots (18 fotos en un A4)
w = 10
h = 10
fig = plt.figure(figsize=(8.3, 11.7)) # en inches
columns = 3
rows = 6
ax = 0
for i in range(1, 19):
    img = mpimg.imread(imagelist3[i])
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
    plt.axis('off')
    plt.subplots_adjust(left=0.1, # esto parece que puede modificar y mover la fig a la derecha, pero no lo hace?
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.4,
                    hspace=0.4)
#plt.savefig("test.png") 
plt.show()
